# %%
# import requests
# import json

# def get_weather(api_key, city):
#     base_url = "http://api.openweathermap.org/data/2.5/weather"
#     params = {
#         "q": city,
#         "appid": api_key,
#         "units": "metric"
#     }
    
#     response = requests.get(base_url, params=params)
#     data = json.loads(response.text)
    
#     if response.status_code == 200:
#         main_weather = data['weather'][0]['main']
#         description = data['weather'][0]['description']
#         temperature = data['main']['temp']
#         humidity = data['main']['humidity']
        
#         print(f"Weather in {city}: {main_weather} ({description})")
#         print(f"Temperature: {temperature}°C")
#         print(f"Humidity: {humidity}%")
#     else:
#         print("Error retrieving weather data.")

# # API 키와 도시명을 설정합니다.
# api_key = "YOUR_API_KEY"
# city = "Seoul"

# # 날씨 데이터를 가져옵니다.
# get_weather(api_key, city)

# %% [markdown]
# * 최저기온 : minTa
# * 최고기온 : maxTa
# * 일강수량 : sumRn

# %%
import requests
import pandas as pd
import json
from pandas import json_normalize

url = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList'
params ={
        'serviceKey' : '8lxQLCYom44tsdf9NkEI825WgTSWu6eD4T9HosL/+19KJ5SLXxX6Q+3Lrfb9JgYLldnoEi03rh1u5CplkTgq6A==',
         'pageNo' : '1',
         'numOfRows' : '10',
         'dataType' : 'json',
         'dataCd' : 'ASOS',
         'dateCd' : 'DAY',
         'startDt' : '20230401',
         'endDt' : '20230510',
         'stnIds' : '108' 
        }

response = requests.get(url, params=params)
raw = response.json()
# data = raw['response']['body']['items']
# df = json_normalize(data['item'])

# print(df.shape)
# print(df.columns)

# col = ['stnNm', 'tm', 'minTa', 'maxTa', 'avgTa', 'sumRn', 'maxWs', 'minRhm']
# df[col]
# # df.head()

# %%
raw
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'stnId': '108',
#       'stnNm': '서울',
#       'tm': '2023-04-01',
#       'avgTa': '17.5',
#       'minTa': '9.4',
#       'minTaHrmt': '0646',
#       'maxTa': '25.6',
#       'maxTaHrmt': '1525',
#       'mi10MaxRn': '',
#       'mi10MaxRnHrmt': '',
#       'hr1MaxRn': '',
#       'hr1MaxRnHrmt': '',
#       'sumRnDur': '',
#       'sumRn': '',
#       'maxInsWs': '7.2',
#       'maxInsWsWd': '250',
#       'maxInsWsHrmt': '1716',
#       'maxWs': '4.5',
#       'maxWsWd': '270',
#       'maxWsHrmt': '1711',
#       'avgWs': '1.8',
#       'hr24SumRws': '1592',
#       'maxWd': '290',
#       'avgTd': '2.8',
#       'minRhm': '19',
#       'minRhmHrmt': '1528',
#       'avgRhm': '40.4',
#       'avgPv': '7.5',
#       'avgPa': '1005.5',
#       'maxPs': '1017.4',
#       'maxPsHrmt': '0153',
#       'minPs': '1012.5',
#       'minPsHrmt': '1646',
# ...
